# %% [markdown]
# # Les bases du Machine Learning

# %% [markdown]
# ![Capture d’écran 2021-07-27 à 11.29.52.png](data:image/png;base64,...)

# %% [markdown]
# # **Le Machine Learning, c'est quoi ?**

# %% [markdown]
# *The area of computational science that focuses on analyzing and interpreting patterns and structures in data to enable learning, reasoning, and decision making outside of human interaction.*
#
#
# Le domaine de la science informatique qui se concentre sur l'analyse et l'interprétation de modèles et de structures dans les données pour permettre l'apprentissage, le raisonnement et la prise de décision en dehors de toute interaction humaine.

# %% [markdown]
# * Le ML est en constante évolution
# * Les bases ne bougeront pas
# * Une veille régulière est nécéssaire

# %% [markdown]
# # **Programmation Vs Machine Learning**

# %% [markdown]
# ![Capture d’écran 2021-07-26 à 16.23.30.png](data:image/png;base64,...)

# %% [markdown]
# # **Machine Learning supervisé Vs non supervisé**

# %% [markdown]
# ![Capture d’écran 2021-07-26 à 16.26.30.png](data:image/png;base64,...)

# %% [markdown]
# # **Machine Learning supervisé**

# %% [markdown]
# La **target** (cible), appelé aussi y ou output, est connu par l'algorithme d'apprentissage.
# L'algorithme utilise les **features** (variables), appelé aussi X ou inputs, pour prédire la cible. L'intêret pour l'algorithme, c'est de prédire la cible lorsque celle-ci n'est pas connu, mais lorsque X est connu. Il est alors possible de prédire la cible pour ces observations (échantillons, lignes ou **samples**).

# %% [markdown]
# ![Capture d’écran 2021-07-26 à 16.28.18.png](data:image/png;base64,...)

# %% [markdown]
# # **Machine Learning non supervisé**

# %% [markdown]
# Cette fois, il n'y a pas de cible. L'algorithme cherche une relation entre les données. Il est alors possible de déterminer des clusters lorsque les observations sont semblables. Ainsi, On trouve quelles observations sont semblables.

# %% [markdown]
# ![Capture d’écran 2021-07-26 à 16.28.35.png](data:image/png;base64,...)

# %% [markdown]
# # **Regression Vs Classification**

# %% [markdown]
# ![Capture d’écran 2021-07-26 à 16.40.43.png](data:image/png;base64,...)

# %% [markdown]
# # **Les différentes étapes d'un projet ML**

# %% [markdown]
# ![Capture d’écran 2021-07-26 à 16.39.48.png](data:image/png;base64,...)

# %% [markdown]
# # **Les différents domaines d'application du Machine Learning**

# %% [markdown]
# ![Capture d’écran 2021-07-26 à 16.42.04.png](data:image/png;base64,...)

# %% [markdown]
# # **Scikit Learn**

# %% [markdown]
# ![Capture d’écran 2021-07-26 à 16.44.10.png](data:image/png;base64,...)

# %% [markdown]
# **Scikit-learn (Sklearn) est une librairie de Machine Learning qui fournit des outils de préprocessing, de modélisation et de sélection de modèles.**

# %% [markdown]
# ▶️https://scikit-learn.org

# %% [markdown]
# * Sklearn est organisé en modules
# * Chaque module contient des outils sous la forme de classe

# %% [markdown]
# ▶️Sklearn [`linear_model`](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.linear_model) documentation

# %% [markdown]
# Le module `linear_model` contient plusieurs algorithmes, qui sont enfait des classes de ce module.

# %% [markdown]
# # **Algorithme** vs **Modèle**

# %% [markdown]
# Même si on les emploi de manière interchangeable:
# * Un algorithme est un "modèle non entraîné".
# * Un algorithme devient un modèle lorsqu'il est entraîné sur des données. Dès lors, il peut faire des prédictions.

# %% [markdown]
# # **La regression linéaire**

# %% [markdown]
# Le premier algorithme que l'on va explorer ensemble est la `régression linéaire`.
#
# * `linear_model` est le module
# * `LinearRegression` est la classe, et aussi l'algorithme

# %%
from sklearn.linear_model import LinearRegression
# not this way: import sklearn.linear_model

model = LinearRegression()

# %% [markdown]
# # Régression linéaire

# %% [markdown]
# > "*Une régression linéaire établit une relation linéaire entre l'entrée `X` et la sortie `y`. Elle optimise le `coefficient` (la pente) `a` et l'`intercept` (l'ordonnée à l'origine) `b` en réduisant au maximum les `résiduels` entre la sortie `y réelle` et la sortie `y prédite``.*"
# $y = ax + b$

# %% [markdown]
# ![Capture d’écran 2021-07-27 à 11.38.26.png](data:image/png;base64,...)

# %% [markdown]
# 👉**Direction Livecode**
